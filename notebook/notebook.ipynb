# %%
# %ac 128 clock ceg
# Out:
# ...
#             <div style="margin: -8px -8px 0 -8px; padding: 0; overflow: hidden;">
#                 <iframe id="ac-iframe-d55c2451" src="https://aesthetic.computer/clock~ceg?nolabel=true&nogap=true&notebook=true&density=2"
#                         width="100%"
#                         height="256"
#                         frameborder="0"
#                         style="background: transparent; margin: 0; padding: 0; border: none; display: block;">
#                 </iframe>
#             </div>
