# %% [markdown]
# # $xkq Variations — KidLisp Keeps Workbook
#
# Variations on `$xkq`, the keep that brought in a new collector at 9 XTZ.
#
# **DNA:** masked zebra boxes + rainbow spin burn + zoom feedback

# %%
import aesthetic

# %% [markdown]
# ## Original $xkq

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3
# Out:
#         <div style="margin: -8px -8px 0 -8px; padding: 0; overflow: hidden;">
#             <iframe id="ac-iframe-19c442bf" src="https://localhost:8888/black~mask_w/2_0_w/2_h,_ink_zebra_8~box_?_?_?~unmask~scroll_(?_0_-1_1)_10~ink_rainbow_48,_line,_spin_3,_burn~zoom_0.25,_scroll_frame*3?nolabel=true&nogap=true&density=2"
#                     width="100%"
#                     height="480"
#                     frameborder="0"
#                     style="background: transparent; margin: 0; padding: 0; border: none; display: block;">
#             </iframe>
#         </div>
#         <pre style="margin-top: 12px; padding: 12px; background: #f9f9f9; border: 1px solid #e0e0e0; border-radius: 4px; font-family: 'Courier New', monospace; font-size: 12px; line-height: 1.5; overflow-x: auto; white-space: pre-wrap; word-wrap: break-word;">
#         black
# ...

# %% [markdown]
# ## 1. Palette Swaps

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink neon 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink fire 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink fire 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink 100 180 255
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink 200 220 255, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %% [markdown]
# ## 2. Mask Geometry

# %%
# %%ac 240
# black
# mask 0 0 w h/2, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3
# Out:
#         <div style="margin: -8px -8px 0 -8px; padding: 0; overflow: hidden;">
#             <iframe id="ac-iframe-bf9876e8" src="https://localhost:8888/black~mask_0_0_w_h/2,_ink_zebra_8~box_?_?_?~unmask~scroll_(?_0_-1_1)_10~ink_rainbow_48,_line,_spin_3,_burn~zoom_0.25,_scroll_frame*3?nolabel=true&nogap=true&density=2"
#                     width="100%"
#                     height="480"
#                     frameborder="0"
#                     style="background: transparent; margin: 0; padding: 0; border: none; display: block;">
#             </iframe>
#         </div>
#         <pre style="margin-top: 12px; padding: 12px; background: #f9f9f9; border: 1px solid #e0e0e0; border-radius: 4px; font-family: 'Courier New', monospace; font-size: 12px; line-height: 1.5; overflow-x: auto; white-space: pre-wrap; word-wrap: break-word;">
#         black
# ...

# %%
# %%ac 240
# black
# mask 0 0 w/3 h/3, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/4 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %% [markdown]
# ## 3. Feedback Tuning

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 1, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.5, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# scroll frame*3

# %% [markdown]
# ## 4. Blend Modes

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, blur
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3
# zoom 0.25, scroll frame*3

# %% [markdown]
# ## 5. Shape Mutations

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# circle ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# line ? ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# circle ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %% [markdown]
# ## 6. Wild Departures

# %%
# %%ac 240
# black
# ink zebra 8
# box ? ? ?
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask 0 0 w/3 h, ink zebra 8
# box ? ? ?
# unmask
# mask w*2/3 0 w/3 h, ink neon 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? ?
# unmask
# scroll (? 0 -1 1) 10
# ink rainbow 48, line, spin -3, burn
# zoom 0.25, scroll frame*3

# %%
# %%ac 240
# black
# mask w/2 0 w/2 h, ink zebra 8
# box ? ? (+ 1 amplitude*50)
# unmask
# scroll (? 0 -1 1) (+ 5 amplitude*20)
# ink rainbow 48, line, spin 3, burn
# zoom 0.25, scroll frame*3
